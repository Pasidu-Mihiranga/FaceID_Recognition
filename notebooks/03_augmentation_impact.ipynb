# %% [markdown]
# # Data Augmentation Ablation Study

# %% [markdown]
# This ablation study determines the impact of color and lighting data augmentation on the final ArcFace recognition accuracy.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print('Ready for augmentation impact analysis.')
